# %%
# !pip install gTTs

# %%
# !pip install google-generativeai
from google.generativeai import GenerativeModel

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown
from gtts import gTTS
from IPython.display import Audio,display


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
def ask_question(name):
  ques = ' hey '  +  name  + ' what do you want  '
  ques = input(ques)
  return ques

# %%
def classify_questions(ques):
    goahead_with_web_browsing = False
    device_lst = ['email', 'message', 'call', 'reminder', 'calculator', 'alarm']
    personal_lst = ['who are you?', 'who created you']

    device = False
    for i in device_lst:
        if i in ques.lower():
            device = True

    if device:
        print('This question is related to a device, which is not supported in this Intellivoice')
        goahead_with_web_browsing = False

    personal_question = False
    for i in personal_lst:
        if i in ques.lower():
            personal_question = True

    if personal_question:
        print('Hey, I am Intellivoice created by Sai')

    if device or personal_question:
        goahead_with_web_browsing = False
    else:
        goahead_with_web_browsing = True

    return goahead_with_web_browsing

classify_questions('who are you?')
# Out:
# Hey, I am Intellivoice created by Sai
# False

# %%
from google.colab import userdata

# %%
userdata.get('api_key')
# Out:
# 'AIzaSyBKA5ORe5It9BhDJt_3pLRXSDKfrzao2CA'

# %%
GOOGLE_API_KEY=userdata.get('api_key')
genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro')

# %%
response = model.generate_content("write a story swatch bharat in india")

# %%
to_markdown(response.text)
# Out:
# > In the heart of India, amidst the bustling streets of its metropolises and the tranquil villages nestled in its countryside, lies a hidden gem known as swatch bharat. Swatch bharat is a story of transformation and revitalisation, a journey of a nation united in its quest for cleanliness and hygiene.
# >
# > It all began with a vision, a dream of a Mahatma, who believed that a clean and healthy India would be a symbol of its progress and development. This vision found its form in the Swatch Bharat Abhiyan, a nationwide campaign launched by Prime Minister Narendra Modi in 2014.
# >
# > The campaign aimed to eliminate open defecation, provide access to safe sanitation, and ensure waste management in both rural and urban areas. It was a daunting task, considering the sheer size of India's population and the deep-rooted cultural and social challenges associated with sanitation and hygiene.
# >
# ...

# %%
def ask_promptpal(ques):
  modified_prompt = '  hey give me answer to this question '+  ques  + ' in a maximum of 80 words  '
  response = model.generate_content(modified_prompt)
  to_markdown(response.text)
  return response.text

# %%
def speak(answer):

  tts = gTTS(answer)
  tts.save('audio.mp3')
  display(Audio('audio.mp3',autoplay=True))

# %%
have_any_other_queries = 'y'
name = ''
while have_any_other_queries=='y':
  if name =='':
    name=input('hey what is your name ? -')

  q = ask_question(name)
  go_ahead = classify_questions(q)
  answer = ''


  if go_ahead == True:
    answer = ask_promptpal(q)
    speak(answer)

    print(answer)

  have_any_other_queries = input(' Do you have any other queries ')
# Out:
# hey what is your name ? -sai
#  hey sai what do you want  who are you
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# I am a comprehensive and informative AI language model, trained by Google to provide helpful and reliable responses to a wide range of questions and prompts. I am designed to understand and generate human language, enabling me to communicate effectively and assist you with various tasks, including answering questions, summarizing information, and providing translations.
#  Do you have any other queries n
